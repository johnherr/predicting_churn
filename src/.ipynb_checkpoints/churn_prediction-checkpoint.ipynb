# %%
import numpy as np
import pandas as pd


import xgboost as xgb
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble.partial_dependence import plot_partial_dependence
from sklearn.ensemble.gradient_boosting import GradientBoostingClassifier

# %%
df_train = pd.read_csv('../data/churn_train.csv')
df_test = pd.read_csv('../data/churn_test.csv')

# %%
def calc_diff(date, dc):
    return (dc-date).days

def preprocessing(data):
    """Take cleaned dataframe and preprocess features to prepare for training
    Parameters
    ----------
    data: a dataframe containing features to be preprocessed and used for training.
    Returns
    -------
    X: A dataframe of preprocessed data ready for training
    """
    data['last_trip_date'] = data['last_trip_date'].astype('datetime64')
    data['signup_date'] = data['signup_date'].astype('datetime64')

    data.loc[:,['avg_rating_by_driver']] = data[['avg_rating_by_driver']].fillna(data[['avg_rating_by_driver']].mean())
    data.loc[:,['avg_rating_of_driver']] = data[['avg_rating_of_driver']].fillna(data[['avg_rating_of_driver']].mean())
    data.loc[:,['phone']] = data[['phone']].replace(np.nan, 'Other')

    data = pd.get_dummies(data, columns=['city','phone'])
    data = data.drop(columns=['city_Astapor', 'phone_Other'])

    col = 'last_trip_date'
    data[col]= pd.to_datetime(data[col])

    dc = pd.Timestamp("2014-07-01")
    data['days_since_last_ride'] = data.apply(lambda row: calc_diff(row['last_trip_date'], dc),axis=1)
    data['churn'] = data['days_since_last_ride']>30

    data_model = data[['avg_dist', 'avg_rating_by_driver', 'avg_rating_of_driver', 'avg_surge'
                   , 'surge_pct', 'trips_in_first_30_days',
       'luxury_car_user', 'weekday_pct', "city_King's Landing",
       'city_Winterfell', 'phone_Android', 'phone_iPhone','churn']]

    X = data_model.copy()
    y = X.pop('churn')
    return X, y

# %%
X_train, y_train = preprocessing(df_train)
X_test, y_test = preprocessing(df_test)

# %%
my_xgb = xgb.XGBClassifier(max_depth=2, learning_rate=0.05, n_estimators=2000, silent=True, 
                            objective='binary:logistic', booster='gbtree', n_jobs=-1, 
                            nthread=None, gamma=0, min_child_weight=1, max_delta_step=0, 
                            subsample=.4, colsample_bytree=1, colsample_bylevel=1, reg_alpha=0, 
                            reg_lambda=1, scale_pos_weight=1, base_score=0.5, random_state=0, 
                            seed=None, missing=None)

# %%
my_xgb.fit(X_train.values, y_train.values)

print('Test Accuracy: ', my_xgb.score(X_test.values, y_test.values))
# Out:
# Test Accuracy:  0.7853

# %%
importances = my_xgb.feature_importances_
indices = np.argsort(importances)[::-1]

plt.figure()
plt.title("Feature importances")
plt.bar(range(len(importances)), importances[indices],
       color="r", align="center", alpha =.5)
plt.xticks(range(X_train.shape[1]), X_train.columns[indices], rotation = 50, ha = 'right')
#plt.xlim([-1, X.shape[1]])
plt.tight_layout()
plt.savefig('../images/feature_importance_grad_boost.png')

# %%
X_train.columns[1]
# Out:
# 'avg_rating_by_driver'

# %%
gbr = GradientBoostingClassifier(learning_rate=0.05, n_estimators=2000, subsample=.4)
gbr.fit(X_train.values, y_train.values)
print('Test Accuracy: ', gbr.score(X_test.values, y_test.values))
# Out:
# Test Accuracy:  0.7843

# %%
coi = 0 # column of interest 
fig, ax = plot_partial_dependence(gbr, X_train, [coi])
ax[0].set_xlabel(X_train.columns[coi])
ax[0].set_ylabel('Partial Dependence')
plt.tight_layout()
plt.savefig('../images/{}.png'.format(X_train.columns[coi]))

# %%
coi = 1 # column of interest
fig, ax = plot_partial_dependence(gbr, X_train, [coi])
ax[0].set_xlabel(X_train.columns[coi])
ax[0].set_ylabel('Partial Dependence')
plt.tight_layout()
plt.savefig('../images/{}.png'.format(X_train.columns[coi]))

# %%
coi = 2 # column of interest (kings landing)
fig, ax = plot_partial_dependence(gbr, X_train, [coi])
ax[0].set_xlabel(X_train.columns[coi])
ax[0].set_ylabel('Partial Dependence')
plt.tight_layout()
plt.savefig('../images/{}.png'.format(X_train.columns[coi]))

# %%
coi = 3 # column of interest (kings landing)
fig, ax = plot_partial_dependence(gbr, X_train, [coi])
ax[0].set_xlabel(X_train.columns[coi])
ax[0].set_ylabel('Partial Dependence')
plt.tight_layout()
plt.savefig('../images/{}.png'.format(X_train.columns[coi]))

# %%
coi = 4 # column of interest (kings landing)
fig, ax = plot_partial_dependence(gbr, X_train, [coi])
ax[0].set_xlabel(X_train.columns[coi])
ax[0].set_ylabel('Partial Dependence')
plt.tight_layout()
plt.savefig('../images/{}.png'.format(X_train.columns[coi]))

# %%
coi = 5 # column of interest (kings landing)
fig, ax = plot_partial_dependence(gbr, X_train, [coi])
ax[0].set_xlabel(X_train.columns[coi])
ax[0].set_ylabel('Partial Dependence')
plt.tight_layout()
plt.savefig('../images/{}.png'.format(X_train.columns[coi]))

# %%
coi = 6 # column of interest (kings landing)
fig, ax = plot_partial_dependence(gbr, X_train, [coi])
ax[0].set_xlabel(X_train.columns[coi])
ax[0].set_ylabel('Partial Dependence')
plt.tight_layout()
plt.savefig('../images/{}.png'.format(X_train.columns[coi]))

# %%
coi = 7 # column of interest (kings landing)
fig, ax = plot_partial_dependence(gbr, X_train, [coi])
ax[0].set_xlabel(X_train.columns[coi])
ax[0].set_ylabel('Partial Dependence')
plt.tight_layout()
plt.savefig('../images/{}.png'.format(X_train.columns[coi]))

# %%
coi = 8 # column of interest (kings landing)
fig, ax = plot_partial_dependence(gbr, X_train, [coi])
ax[0].set_xlabel(X_train.columns[coi])
ax[0].set_ylabel('Partial Dependence')
plt.tight_layout()
plt.savefig('../images/{}.png'.format(X_train.columns[coi]))

# %%
coi = 9 # column of interest (kings landing)
fig, ax = plot_partial_dependence(gbr, X_train, [coi])
ax[0].set_xlabel(X_train.columns[coi])
ax[0].set_ylabel('Partial Dependence')
plt.tight_layout()
plt.savefig('../images/{}.png'.format(X_train.columns[coi]))

# %%
coi = 10 # column of interest (kings landing)
fig, ax = plot_partial_dependence(gbr, X_train, [coi])
ax[0].set_xlabel(X_train.columns[coi])
ax[0].set_ylabel('Partial Dependence')
plt.tight_layout()
plt.savefig('../images/{}.png'.format(X_train.columns[coi]))

# %%
coi = 11 # column of interest (kings landing)
fig, ax = plot_partial_dependence(gbr, X_train, [coi])
ax[0].set_xlabel(X_train.columns[coi])
ax[0].set_ylabel('Partial Dependence')
plt.tight_layout()
plt.savefig('../images/{}.png'.format(X_train.columns[coi]))

# %%
coi = 12 # column of interest (kings landing)
fig, ax = plot_partial_dependence(gbr, X_train, [coi])
ax[0].set_xlabel(X_train.columns[coi])
ax[0].set_ylabel('Partial Dependence')
plt.savefig('../images/{}.png'.format(X_train.columns[coi]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/partial_dependence.py in plot_partial_dependence(gbrt, X, features, feature_names, label, n_cols, grid_resolution, percentiles, n_jobs, verbose, ax, line_kw, contour_kw, **fig_kw)
#     307             for i in fxs:
# --> 308                 l.append(feature_names[i])
#     309             names.append(l)
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-8d02a4fc0976> in <module>
#       1 coi = 12 # column of interest (kings landing)
# ----> 2 fig, ax = plot_partial_dependence(gbr, X_train, [coi])
#       3 ax[0].set_xlabel(X_train.columns[coi])
#       4 ax[0].set_ylabel('Partial Dependence')
# ...

# %%
rf = RandomForestClassifier(n_estimators=200, max_depth=10, n_jobs=-2)
rf.fit(X_train,y_train)
y_predicted = rf.predict(X_test)

# %%
print('Test Accuracy: ', rf.score(X_test.values, y_test.values))
# Out:
# Test Accuracy:  0.7748

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

plt.figure()
plt.title("Feature importances")
plt.bar(range(len(importances)), importances[indices],
       color="r", align="center", alpha =.5)
plt.xticks(range(X_train.shape[1]), X_train.columns[indices], rotation = 50, ha = 'right')
#plt.xlim([-1, X.shape[1]])
plt.tight_layout()
plt.savefig('../images/random_forest_importances.png')

# %%
logit = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial').fit(X_train, y_train)
logit.score(X_test, y_test)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# 0.7086

# %%
logit.get_params
# Out:
# <bound method BaseEstimator.get_params of LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='multinomial',
#           n_jobs=None, penalty='l2', random_state=0, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)>

# %%
coeficients = logit.coef_[0]
#coeficients = np.abs(coeficients)
indices = np.argsort(coeficients)[::-1]

plt.figure()
plt.title("|Coefficients| for Logisitic Regression Model")
plt.bar(range(len(coeficients)), coeficients[indices],
       color="r", align="center", alpha =.5)
plt.xticks(range(X_train.shape[1]), X_test.columns[indices], rotation = 50, ha = 'right')
#plt.xlim([-1, X.shape[1]])
plt.show()

# %%
a = col

# %%
important = col

# %%
X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-185-2792080b455f> in <module>
#       1 df2 = X_train
# ----> 2 pd.concat(X_train,y_train)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     226                        keys=keys, levels=levels, names=names,
#     227                        verify_integrity=verify_integrity,
# --> 228                        copy=copy, sort=sort)
#     229     return op.get_result()
#     230
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     242             raise TypeError('first argument must be an iterable of pandas '
# ...

# %%
X_train['city_King\'s Landing'].sum()/X_train.shape[0]
# Out:
# 0.2036

# %%
df = pd.concat([df_train, df_test])

# %%
df.columns
# Out:
# Index(['avg_dist', 'avg_rating_by_driver', 'avg_rating_of_driver', 'avg_surge',
#        'city', 'last_trip_date', 'phone', 'signup_date', 'surge_pct',
#        'trips_in_first_30_days', 'luxury_car_user', 'weekday_pct'],
#       dtype='object')

# %%
df = df[[]]

# %%
sns.pairplot(df)
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:778: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   a, weights = _ravel_and_check_weights(a, weights)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py in _unsigned_subtract(a, b)
#     341     try:
# --> 342         dt = signed_to_unsigned[dt.type]
#     343     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-204-1a6fe1782b2f> in <module>
# ----> 1 sns.pairplot(df)
#
# ...
